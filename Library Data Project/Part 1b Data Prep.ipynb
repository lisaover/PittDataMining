# %% [markdown]
# ## Humanities Digital Archives Project, Part 1b Data Prep
# Shruti Gupta, Lisa Over, L. Sooter

# %%
import warnings;
warnings.filterwarnings('ignore');

# %%
# Import libraries
import pandas as pd
import numpy as np
import nltk
import re
import copy
import contractions
import spacy
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %% [markdown]
# ### Load for_prep_items.csv

# %%
# Load Islandora items metadata csv file
pd.set_option('display.max_columns', None)
items = pd.read_csv('for_prep_items.csv', encoding='latin-1', dtype='unicode')

# Display the head
items.head()
# Out:
#   Unnamed: 0  Identifier                                             Title  \
# 0          0  000001.PIC                                         Musicians
# 1          1   000001.UE                        Sylvania Locals Conference
# 2          2  000002.PIC              USMC Pilot with McDonnell FH Phantom
# 3          3   000002.UE                                      Soup Kitchen
# 4          4  000003.PIC  Greater Pittsburgh International Airport Opening
#
#                      Creator            Sort Date Type of Resource  \
# 0               Paul Slantis  1950-01-01T00:00:00      still image
# 1  United Electrical Workers  1945-04-29T00:00:00      still image
# 2               Paul Slantis  1950-01-01T00:00:00      still image
# 3  United Electrical Workers  1940-01-01T00:00:00      still image
# 4               Paul Slantis  1952-05-31T00:00:00      still image
#
#         Genre                                           Abstract  \
# 0  photograph  Six young African-American males playing percu...
# 1  photograph  Leaders of Sylvania Locals. Front row (L-R): L...
# 2  photograph  United States Marine Corps pilot with his McDo...
# 3  photograph  Drinking donated coffee at Johnsonburg Plant S...
# 4  photograph  US Navy airplanes lined up on the tarmac of th...
#
#                                               Source    Site Membership  \
# 0  Paul Slantis Photograph Collection, ca. 1946-1...  HistPitt, Digital
# 1  UE News Photograph Collection, 1933-1998UE New...  HistPitt, Digital
# 2  Paul Slantis Photograph Collection, ca. 1946-1...  HistPitt, Digital
# 3  UE News Photograph Collection, 1933-1998UE New...  HistPitt, Digital
# 4  Paul Slantis Photograph Collection, ca. 1946-1...  HistPitt, Digital
#
#   Collection Membership                                           Ttle_Abs
# 0         collection.68  Musicians. Six young African-American males pl...
# 1         collection.89  Sylvania Locals Conference. Leaders of Sylvani...
# 2         collection.68  USMC Pilot with McDonnell FH Phantom. United S...
# 3         collection.89  Soup Kitchen. Drinking donated coffee at Johns...
# 4         collection.68  Greater Pittsburgh International Airport Openi...

# %% [markdown]
# #### Combine Abstract and Title

# %%
# Replace NaN with empty string
items = items.replace(np.nan, '', regex=True)

# %%
items['Ttle_Abs'] = items['Title'].values + '. ' + items['Abstract'].values

# %%
items['Ttle_Abs'].head()
# Out:
# 0    Musicians. Six young African-American males pl...
# 1    Sylvania Locals Conference. Leaders of Sylvani...
# 2    USMC Pilot with McDonnell FH Phantom. United S...
# 3    Soup Kitchen. Drinking donated coffee at Johns...
# 4    Greater Pittsburgh International Airport Openi...
# Name: Ttle_Abs, dtype: object

# %% [markdown]
# #### Correct spelling in items dataset

# %%
nltk.download('words')
words = set(nltk.corpus.words.words())
# Out:
# [nltk_data] Downloading package words to /Users/lisaover/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
# Create a file with words not in English dictionary
word_lst = []
for i in range(len(items)):
    # define punctuation
    punctuations = '''!()[]{};:'"\,<>./?@#$%^&*_~'''
    # remove punctuation from the string
    no_punct = ''
    
    w_lst = items['Ttle_Abs'].iloc[i].split(' ')
    
    for w in w_lst:
        for char in w:
            if char not in punctuations and char is not None:
                no_punct = no_punct + char
        if no_punct != '' and no_punct not in words:
            word_lst.append(no_punct)
        no_punct = ''
with open('nodict_abstract.txt', 'w') as filehandle:
    for item in word_lst:
        filehandle.write('%s\n' % item)

# %%
# Correct obvious spelling issues
def correct_spelling(t):
    r = t.lower()
    r = r.replace('pittsburghã\x95s', 'pittsburgh')
    r = r.replace('&amp;', ' ')
    r = r.replace(' edu ', ' education ')
    # post office and post gazette were lumped together because of 'post' - no bigram created for them
    r = r.replace('post office', 'post_office') 
    r = r.replace('post gazette', 'post_gazette')
    r = r.replace("ã•", "'")
    r = r.replace("ã","")
    r = r.replace("ãs", "'s")
    r = r.replace('ã', '')
    # us was considered pronoun and messes with the data cleaning
    r = r.replace('us navy', 'united states navy') 
    r = r.replace('presenation', 'presentation')
    #r = r.replace('african american', 'african-american')
    r = r.replace('compenstaion', 'compensation')
    r = r.replace('dapartment', 'department')
    r = r.replace('buisiness', 'business')
    r = r.replace('roomlibrary', 'room library')
    r = r.replace('pennsylvania1', 'pennsylvania')
    r = r.replace('suporting', 'supporting')
    r = r.replace('photgrapher', 'photographer')
    r = r.replace('exibition', 'exhibition')
    r = r.replace('managementtogetherto', 'management together to')
    r = r.replace('profie', 'profile')
    r = r.replace('alittle', 'a little')
    r = r.replace('aformentioned', 'aforementioned')
    r = r.replace('constuctign', 'construction')
    r = r.replace('simulatneously', 'simultaneously')
    r = r.replace('constuction', 'construction')
    r = r.replace('constuctor', 'constructor')
    r = r.replace('colellection', 'collection')
    r = r.replace('photogrpah', 'photograph')
    r = r.replace('volunter', 'volunteer')
    r = r.replace('friendrelativearistocrat', 'friend relative aristocrat')
    r = r.replace('passsed', 'passed')
    r = r.replace('adminstration', 'administration')
    r = r.replace('administrationbook', 'administration book')
    r = r.replace('agendabook', 'agenda book')
    r = r.replace('presbyterianuniversity', 'presbyterian university')
    r = r.replace('ttwenty', 'twenty')
    r = r.replace('acomplishments', 'accomplishments')
    r = r.replace('univesity', 'university')
    r = r.replace('|||', ' ')
    r = r.replace('communictions', 'communications')
    r = r.replace(' - ', '-')
    r = r.replace('- ', '-')
    r = r.replace(' -', '-')
    r = r.replace('--', ' ')
    
    # Remove URLs
    pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    r = pattern.sub('', r)
    
    pattern = re.compile('www(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    r = pattern.sub('', r)
    
    pattern = re.compile('msp33(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    r = pattern.sub('', r)
    
    pattern = re.compile('msp80(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    r = pattern.sub('', r)
    
    pattern = re.compile('msp117(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    r = pattern.sub('', r)
    
    pattern = re.compile('msp285(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    r = pattern.sub('', r)
    
    pattern = re.compile('201000(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    r = pattern.sub('', r)
    
    return r

# %%
items['Abstract_cspell'] = items.apply(lambda txt: correct_spelling(txt['Ttle_Abs']), axis=1)

# %%
word_lst = []
for i in range(len(items)):
    # define punctuation
    punctuations = '''!()[]{};:'"\,<>./?@#$%^&*_~'''
    # remove punctuation from the string
    no_punct = ''
    
    w_lst = items['Abstract_cspell'].iloc[i].split(' ')
    
    for w in w_lst:
        for char in w:
            if char not in punctuations and char is not None:
                no_punct = no_punct + char
        if no_punct != '' and no_punct not in words:
            word_lst.append(no_punct)
        no_punct = ''
with open('nodict_cspell.txt', 'w') as filehandle:
    for item in word_lst:
        filehandle.write('%s\n' % item)

# %% [markdown]
# #### Expand contractions

# %% [markdown]
# https://stackoverflow.com/questions/49828463/running-replace-contractions-across-all-text-files-in-same-directory-and-outpu

# %%
def replace_contractions(text):
    """Replace contractions in string of text"""
    return contractions.fix(str(text))

# %%
# Call replace_contractions
items['Abstract_noc'] = items.apply(lambda txt: replace_contractions(txt['Abstract_cspell']), axis=1)

# %% [markdown]
# #### Remove stop words, punctuation, and special characters

# %%
# https://www.geeksforgeeks.org/removing-stop-words-nltk-python/
def clean_text(t):
    text = re.sub(r"[^a-zA-Z0-9]"," ",t)
    stop_words = set(stopwords.words('english')) 
    word_tokens = word_tokenize(text) 
    filtered_sentence = [w for w in word_tokens if not w in stop_words] 
    filtered_sentence = [] 
  
    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w) 
    
    return ' '.join(filtered_sentence)

# %%
# Call clean_text
items['Abstract_clean'] = items.apply(lambda txt: clean_text(txt['Abstract_noc']), axis=1)

# %%
items.head()
# Out:
#   Unnamed: 0  Identifier                                             Title  \
# 0          0  000001.PIC                                         Musicians
# 1          1   000001.UE                        Sylvania Locals Conference
# 2          2  000002.PIC              USMC Pilot with McDonnell FH Phantom
# 3          3   000002.UE                                      Soup Kitchen
# 4          4  000003.PIC  Greater Pittsburgh International Airport Opening
#
#                      Creator            Sort Date Type of Resource  \
# 0               Paul Slantis  1950-01-01T00:00:00      still image
# 1  United Electrical Workers  1945-04-29T00:00:00      still image
# 2               Paul Slantis  1950-01-01T00:00:00      still image
# 3  United Electrical Workers  1940-01-01T00:00:00      still image
# 4               Paul Slantis  1952-05-31T00:00:00      still image
#
#         Genre                                           Abstract  \
# 0  photograph  Six young African-American males playing percu...
# 1  photograph  Leaders of Sylvania Locals. Front row (L-R): L...
# 2  photograph  United States Marine Corps pilot with his McDo...
# 3  photograph  Drinking donated coffee at Johnsonburg Plant S...
# 4  photograph  US Navy airplanes lined up on the tarmac of th...
#
#                                               Source    Site Membership  \
# 0  Paul Slantis Photograph Collection, ca. 1946-1...  HistPitt, Digital
# 1  UE News Photograph Collection, 1933-1998UE New...  HistPitt, Digital
# 2  Paul Slantis Photograph Collection, ca. 1946-1...  HistPitt, Digital
# 3  UE News Photograph Collection, 1933-1998UE New...  HistPitt, Digital
# 4  Paul Slantis Photograph Collection, ca. 1946-1...  HistPitt, Digital
#
#   Collection Membership                                           Ttle_Abs  \
# 0         collection.68  Musicians. Six young African-American males pl...
# 1         collection.89  Sylvania Locals Conference. Leaders of Sylvani...
# 2         collection.68  USMC Pilot with McDonnell FH Phantom. United S...
# 3         collection.89  Soup Kitchen. Drinking donated coffee at Johns...
# 4         collection.68  Greater Pittsburgh International Airport Openi...
#
#                                      Abstract_cspell  \
# 0  musicians. six young african-american males pl...
# 1  sylvania locals conference. leaders of sylvani...
# 2  usmc pilot with mcdonnell fh phantom. united s...
# 3  soup kitchen. drinking donated coffee at johns...
# 4  greater pittsburgh international airport openi...
#
#                                         Abstract_noc  \
# 0  musicians. six young african-american males pl...
# 1  sylvania locals conference. leaders of sylvani...
# 2  usmc pilot with mcdonnell fh phantom. united s...
# 3  soup kitchen. drinking donated coffee at johns...
# 4  greater pittsburgh international airport openi...
#
#                                       Abstract_clean
# 0  musicians six young african american males pla...
# 1  sylvania locals conference leaders sylvania lo...
# 2  usmc pilot mcdonnell fh phantom united states ...
# 3  soup kitchen drinking donated coffee johnsonbu...
# 4  greater pittsburgh international airport openi...

# %% [markdown]
# #### Lemmatize words

# %%
nlp = spacy.load('en', parse=True, tag=True, entity=True)

# %%
def lemmatize_text(text):
    text = nlp(text)
    text = ' '.join([word.lemma_ if word.lemma_ != '_PRON_' else word.text for word in text])
    return text

# %%
# Call lemmatize_text
items['Abstract_lemma'] = items.apply(lambda txt: lemmatize_text(txt['Abstract_clean']), axis=1)

# %% [markdown]
# #### Eliminate nulls/empty fields and write dataset to file

# %%
# Only items where Abstract is not null, i.e., Abstract exists in items file
items2 = items[items['Abstract_lemma'].notnull()]
items2.shape
# Out:
# (124539, 16)

# %%
# Only items where Abstract is not null, i.e., Abstract exists in items file
items2 = items[(items['Abstract_cspell'].values != '') & (items['Abstract_lemma'].values != '')]
items2.shape
# Out:
# (124517, 16)

# %%
items2['Abstract_lemma'].isnull().sum()
# Out:
# 0

# %%
items2.to_csv(r'for_models_items.csv')

# %% [markdown]
# ### Load for_prep_combined.csv

# %%
# Load combined items/finding aids csv file
pd.set_option('display.max_columns', None)
comb = pd.read_csv('for_prep_combined.csv', encoding='latin-1', dtype='unicode')

# Display the head
comb.head()
# Out:
#   Unnamed: 0      ItemID                                             cTitle  \
# 0          0  000001.PIC                           Paul Slantis Photographs
# 1          1   000001.UE   United Electrical, Radio, and Machine Workers...
# 2          2  000002.PIC                           Paul Slantis Photographs
# 3          3   000002.UE   United Electrical, Radio, and Machine Workers...
# 4          4  000003.PIC                           Paul Slantis Photographs
#
#                                              iTitle  \
# 0                                         Musicians
# 1                        Sylvania Locals Conference
# 2              USMC Pilot with McDonnell FH Phantom
# 3                                      Soup Kitchen
# 4  Greater Pittsburgh International Airport Opening
#
#                     iCreator           iSort Date iType of Resource  \
# 0               Paul Slantis  1950-01-01T00:00:00       still image
# 1  United Electrical Workers  1945-04-29T00:00:00       still image
# 2               Paul Slantis  1950-01-01T00:00:00       still image
# 3  United Electrical Workers  1940-01-01T00:00:00       still image
# 4               Paul Slantis  1952-05-31T00:00:00       still image
#
#        iGenre                                          iAbstract  \
# 0  photograph  Six young African-American males playing percu...
# 1  photograph  Leaders of Sylvania Locals. Front row (L-R): L...
# 2  photograph  United States Marine Corps pilot with his McDo...
# 3  photograph  Drinking donated coffee at Johnsonburg Plant S...
# 4  photograph  US Navy airplanes lined up on the tarmac of th...
#
#                                              iSource   iSite Membership  \
# 0  Paul Slantis Photograph Collection, ca. 1946-1...  HistPitt, Digital
# 1  UE News Photograph Collection, 1933-1998UE New...  HistPitt, Digital
# 2  Paul Slantis Photograph Collection, ca. 1946-1...  HistPitt, Digital
# 3  UE News Photograph Collection, 1933-1998UE New...  HistPitt, Digital
# 4  Paul Slantis Photograph Collection, ca. 1946-1...  HistPitt, Digital
#
#   iCollection Membership  faAcq Number                faID  \
# 0          collection.68  AIS.1991.19a  US-PPiU-ais199119a
# 1          collection.89       UE.14.1      US-PPiU-UE14-1
# 2          collection.68  AIS.1991.19a  US-PPiU-ais199119a
# 3          collection.89       UE.14.1      US-PPiU-UE14-1
# 4          collection.68  AIS.1991.19a  US-PPiU-ais199119a
#
#            faTitle of Collection faTemporal Coverage  \
# 0       Paul Slantis Photographs       ca. 1946-1956
# 1  UE News Photograph Collection           1933-1998
# 2       Paul Slantis Photographs       ca. 1946-1956
# 3  UE News Photograph Collection           1933-1998
# 4       Paul Slantis Photographs       ca. 1946-1956
#
#                                           faAbstract  \
# 0  The Paul Slantis Photographs contain 1,508 4x5...
# 1  This collection contains photographs dating fr...
# 2  The Paul Slantis Photographs contain 1,508 4x5...
# 3  This collection contains photographs dating fr...
# 4  The Paul Slantis Photographs contain 1,508 4x5...
#
#                                  faScope and Content  \
# 0  The collection contains approximately 1,508 4x...
# 1  This collection contains photographs dating fr...
# 2  The collection contains approximately 1,508 4x...
# 3  This collection contains photographs dating fr...
# 4  The collection contains approximately 1,508 4x...
#
#                                     faSub Heading(s)  \
# 0  Greater Pittsburgh International Airport.|||La...
# 1  Carey, James B.|||Carter, Jimmy, 1924-|||Chave...
# 2  Greater Pittsburgh International Airport.|||La...
# 3  Carey, James B.|||Carter, Jimmy, 1924-|||Chave...
# 4  Greater Pittsburgh International Airport.|||La...
#
#                                     faBio or History
# 0  A native of Pittsburgh's Oakland neighborhood,...
# 1  In 1939, the UE News replaced the People's Pre...
# 2  A native of Pittsburgh's Oakland neighborhood,...
# 3  In 1939, the UE News replaced the People's Pre...
# 4  A native of Pittsburgh's Oakland neighborhood,...
